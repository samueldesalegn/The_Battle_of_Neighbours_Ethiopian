# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#   # Capstone Project- The Battle of the Neighborhoods

# %% [markdown]
# #### August 2, 2020
# by Samuel Desalegn Tumdedo

# %% [markdown]
# ## 1.  Introduction
#
# ### 1.1  Background

# %% [markdown]
# As of 2020, the population of Toronto is 6,197,000 which indicates the most populus city in Canada. This metropolitan city is an international center for arts, sports, businesses, cultures and finances which makes it one of the most cosmopolitan and multicultural cities in the world. In the coming ten years, it is predicted that this population figure will be eight million according to the star "< https://www.thestar.com/news/gta/2020/01/31/the-population-of-the-toronto-area-will-hit-8-million-in-the-next-10-years-its-make-or-break-time-are-we-ready.html >"

# %% [markdown]
# Toronto since its old name York have been known for her welcoming nature of people from all over the world. People travelled and lived in Toronto area since more than 12,000 years. York was the name the Toronto area before Toronto being named in 1834 and it was designated as the capital of the province of Ontario in 1867 during Canadian Confederation. The Great Irish Famine (1845–1849) brought a large number of Irish into the city, a slight majority of whom were protestants according to Torontos wikipedia page. After that people started coming from all over the world.

# %% [markdown]
# ### 1.2 Problem Statement

# %% [markdown]
# As part of the partial fulfillment of IBM Data Science Professional certificate, I wanted to give insights for those who want to open Ethiopian restaurant in Toronto area. As we can see from data analysis on segmentation and clustering section of the capstone project, we can conclude that Ethiopian cuisine is not known yet. Ethiopian 'Enjera' is gluten free which means a healthy food. Ethiopian coffee is also the most famous and Ethiopia is where coffee originates. As most people are not aware of Ethiopian food and also Ethiopian business owners least likely be aware of these api technologies.
#
# In the whole of Toronto city and its neighbors, there is only one Ethiopian restaurant by the name "Lalibela cuisine". For those who love Ethiopian coffee and food, currently there are not much options. And I also see the gap in promoting the Ethiopian cuisine.

# %% [markdown]
# ## 2 Object of the project

# %% [markdown]
# The objective of this project is proposing Ethiopian cuisines for business owners which will help customer have easy access to the Ethiopian food they love and also using the foursquare api locating the best places avoid competition. The aim also includes studying and analyzing the neighborhoods of Toronto city and group them into similar clusters, and analyzing those clusters to gather meaningful information. The information will us to help us find what infomation and where. For example, what coffee shop is available where.
#
# During my travel around the world, I have seen a lot people loving Ethiopian cuisine but the access is limitted and my another objective is promoting the Ethiopian cuisine for those who read the report. The project analyzes the available wikipedia data and form clusters using foursquare api and other machine learning tools. Therefore, the project will create awareness for customers of Ethiopian cuisine, and also help business owner to incorporate the technologies into their businesses.

# %% [markdown]
# ## 3 Methodology

# %% [markdown]
# FourSquare provides a comprehensive API, one of the things that API does not easily support is a mechanism to directly extract the top N sites / venues in a given city. This data, however, is easily available directly from the FourSquare Website. To do this simply go to www.foursquare.com, enter the city of your choise and select Top Picks from I'm Looking For selection field.
#
# ### 3.1 Data Sources
# Using BeautifulSoup and Requests the results of the Top Pick for Toronto neighbors was retrieved. Over all python has many more libraries to import and also vizualize data. To build these clusters we used the wikipedia data "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M" and many wrangling, transforming and also cleaning happened using the methods we learned capstone project such as clustering, segmenting, etc.
#
# Coordinate data for each Neighborhood in Toronto: The following csv file gave us the geographical coordinates of each postal code:  http://cocl.us/Geospatial_data

# %% [markdown]
# ### 3.2 Gathering wikipedia data into pandas
#
#
# To start with our analysis, we used the BeautifulSoup package to transform the data in the table on the Wikipedia page into the below pandas dataframe. and we had the following sample output after cleaning the raw data.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We also combined the csv data to get location coordinates as shown on the below table:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.3 Generating a map of Toronto neighbourhood
#
# The next step was generating map using the python folium library to visualize geographic details of Toronto and its neighboorhood. The map of Toronto with boroughs superimposed on top using the latitude and longitude values to get the visual as below:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.4 Clustering
#
# The next step was clustering and segmenting using Foursquare API to explore the neighborhoods. We set the LIMIT parameter to 100, which would limit the number of venues returned by the Foursquare API and the radius of 500 meter. Here is a head of the list of Nearby Venues for the neighborhoods:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.5 Analyzing the neighbourhoods
#
# We used One Hot Encoding, the neighborhood to group data, and find out the top ten venues present in each neighborhood.
#
# ![image.png](attachment:image.png)
#
# Unsupervised learning K-means algorithm was used to cluster the neighborhoods. K-Means algorithm is one of the most common method for clustering in unsupervised learning. Therefore k_cluster value of 5 was used to split the neighborhoods into 5 different clusters based on the similarity they have concerning the venues they contain.

# %% [markdown]
# ## 4.0 Results of the analysis
#
# The following table compiles the results according to our analysis:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4.1 Clustering Map
#
# The following map is the output of the analysis for clustering:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5. Project Conclusion and Recommendation
#
# In a fast growing technologies, one must adapt to the operation environment and make use of the available technologies. Foursquare api and also the clustering mechanisms of supervised and unsupervised data brought great wealth of technologies for everybody. This makes things accessible from a click of button.
#
# Analyzing these data, I was interested to see Ethiopian cuisine in Toronto neighbourhood but the number of Ethiopian restaurants in the area are not enough. This project delivers the insight for business owner to consider Ethiopian cuisines either in their restaurants or open new ones as the Ethiopian cuisine is healthy. For example, Ethiopian "Enjera"is gluten free and fast growing cuisine in the world.
#
# One can explore this analysis and maps, and can decide where to have one, and I will leave the further analysis of the cost benefit and also which area would be less competitive to the business owner!

# %% [markdown]
#                                                           ---- Samuel Desalegn Tumdedo ------------
#                                                           ----      Thank you --------------------
#                                                          ------- Grateful to Coursera and IBM -----
